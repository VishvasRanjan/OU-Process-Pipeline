# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from numba import njit
from tqdm.notebook import tqdm

# %%
# ORNSTEIN-UHLENBECK PARAMETERS
# Mean growth rate (hour^-1)
mu = 1.0
# Doubling time at mean growth rate: T_d = ln(2) / mu
T_d = np.log(2) / mu
# Correlation timescale: "a couple of cell doublings" ≈ 2 * T_d
tau = 2 * T_d
# Mean reversion rate: θ = 1/τ
theta = 1 / tau
# For OU process: fluctuation_scale = σ / sqrt(2θ)
# Therefore: σ = fluctuation_scale * sqrt(2θ)
fluctuation_scale = 0.2  # per hour
sigma = fluctuation_scale * np.sqrt(2 * theta)
print(f"Ornstein-Uhlenbeck parameters:")
print(f"Doubling time at μ = {mu} hour⁻¹: {T_d:.3f} hours")
print(f"τ: {tau:.3f} hours")
print(f"θ: {theta:.3f} hour⁻¹")
print(f"σ: {sigma:.3f} hour⁻¹.⁵")
T_total = 4.5 #Total time (hours)
dt = T_total / 1000  # time step (hours)
t = np.arange(0, T_total, dt)
n_points = len(t)
print(f"Δt: = {dt:.4f} hours")
print(f"Total simulation time: {T_total} hours")
print(f"Number of time points: {n_points}")
# Out:
# Ornstein-Uhlenbeck parameters:
# Doubling time at μ = 1.0 hour⁻¹: 0.693 hours
# τ: 1.386 hours
# θ: 0.721 hour⁻¹
# σ: 0.240 hour⁻¹.⁵
# Δt: = 0.0045 hours
# Total simulation time: 4.5 hours
# Number of time points: 1001

# %%
def simulate_g_np(n_points, mu, theta, sigma, dt, rng):
    g = np.zeros(n_points)
    g[0] = rng.normal(
        loc=mu,
        scale=sigma / np.sqrt(2 * theta)
    )
    alpha = np.exp(-theta * dt)
    beta  = sigma * np.sqrt((1 - np.exp(-2 * theta * dt)) / (2 * theta))
    
    for i in range(n_points - 1):
        mean = alpha * g[i] + (1 - alpha) * mu
        g[i + 1] = rng.normal(mean, beta)
    return g

# %%
rng_data = np.random.RandomState(42)

# %%
def generate_dataset(N_traj, n_points, dt, mu, theta, sigma, sigma_rel=0.035, A0=250.0, rng=np.random.RandomState(42)):
    alpha = np.exp(-theta * dt)
    var_g = (sigma**2 / (2 * theta)) * (1 - alpha**2)
    var_X = (sigma**2 / theta**2) * (dt - (2 / theta) * (1 - alpha) + (1 / (2 * theta)) * (1 - alpha**2))
    cov_gX = (sigma**2 / (2 * theta**2)) * (1 - alpha)**2
    cov_matrix = np.array([
        [var_g, cov_gX],
        [cov_gX, var_X]
    ])
    sigma_n = (sigma_rel * np.sqrt(2)) / dt
    target_sigma_n = sigma_n
    G_list, A_true_list, A_obs_list, Y_noisy_list = [], [], [], []
    for _ in range(N_traj):
        g = np.zeros(n_points)
        X = np.zeros(n_points)
        g[0] = rng.normal(loc=mu,scale=sigma / np.sqrt(2 * theta))
        X[0] = np.log(A0)
        vari = rng.multivariate_normal([0, 0], cov_matrix, size=n_points - 1)
        for i in range(n_points - 1):
            mean_g = g[i] * alpha + mu * (1 - alpha)
            mean_X = X[i] + mu * dt + (g[i] - mu) * (1 - alpha) / theta
            g[i+1] = mean_g + vari[i, 0]
            X[i+1] = mean_X + vari[i, 1]
        A_true = np.exp(X)
        A_obs = A_true * rng.normal(1.0, sigma_rel, size=n_points)
        Y_noisy = np.zeros(n_points)
        for i in range(1, n_points):
            Y_noisy[i] = (np.log(A_obs[i]) - np.log(A_obs[i-1])) / dt
        Y_noisy[0] = Y_noisy[1]
        G_list.append(g)
        A_true_list.append(A_true)
        A_obs_list.append(A_obs)
        Y_noisy_list.append(Y_noisy)
    print(f"Successfully generated {N_traj} exact joint trajectories.")
    print(f"Applied Area Fuzz: {sigma_rel*100:.2f}% per frame to achieve sigma_n ~ {target_sigma_n}")
    
    return G_list, A_true_list, A_obs_list, Y_noisy_list

# %%
G_list, A_true_list, A_obs_list, Y_noisy_list = generate_dataset(N_traj=10, n_points=n_points, dt=dt, mu=mu, theta=theta, sigma=sigma, target_sigma_n=0.20, rng=rng_data)
# Out:
# Successfully generated 10 exact joint trajectories.
# Applied Area Fuzz: 0.06% per frame to achieve sigma_n ~ 0.2

# %%
A_true = A_true_list[0]
A_obs = A_obs_list[0]
Y_noisy = Y_noisy_list[0]
g_true = G_list[0]
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8), sharex=True)
ax1.plot(t, A_true, color='blue', linewidth=3, label='True Cell Area (Biology)')
ax1.scatter(t, A_obs, color='black', s=15, alpha=0.6, label=f'Microscope Observation (DeLTA Area)')
ax1.set_title("How Segmentation Noise Corrupts Perfect Biological Growth", fontsize=14, fontweight='bold')
ax1.set_ylabel("Cell Area (Pixels)", fontsize=12)
ax1.legend(loc='upper left')
ax1.grid(True, alpha=0.3)
ax2.plot(t, g_true, color='blue', linewidth=3, label='True Biological Growth Rate')
ax2.plot(t, Y_noisy, color='gray', linewidth=1.5, alpha=0.8, label='Calculated Noisy Growth Rate ($Y_t$)')
ax2.axhline(0, color='red', linestyle='--', linewidth=2, label='Zero Growth (Optical "Shrinking")')
ax2.set_xlabel("Time (Hours)", fontsize=12)
ax2.set_ylabel("Growth Rate (1/hr)", fontsize=12)
ax2.legend(loc='upper right')
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
def Likelihood(log_A_obs, dt, mu, theta, sigma, sigma_n):
    n_steps = len(log_A_obs)
    alpha = np.exp(-theta * dt)
    F = np.array([
        [1.0, (1.0 - alpha) / theta],  
        [0.0, alpha]            
    ])
    U = np.array([
        mu * dt - mu * (1.0 - alpha) / theta,
        mu * (1.0 - alpha)
    ])
    var_g = (sigma**2 / (2 * theta)) * (1 - alpha**2)
    var_X = (sigma**2 / theta**2) * (dt - (2 / theta) * (1 - alpha) + (1 / (2 * theta)) * (1 - alpha**2))
    cov_gX = (sigma**2 / (2 * theta**2)) * (1 - alpha)**2
    Q = np.array([
        [var_X, cov_gX],
        [cov_gX, var_g]
    ])
    H = np.array([[1.0, 0.0]])
    R = np.array([[sigma_n**2]])
    z_filt = np.zeros((n_steps, 2))  # z_{t|t}
    P_filt = np.zeros((n_steps, 2, 2)) # P_{t|t}
    z_pred = np.zeros((n_steps, 2))  # z_{t|t-1}
    P_pred = np.zeros((n_steps, 2, 2)) # P_{t|t-1}
    z_filt[0] = np.array([log_A_obs[0], mu]) 
    P_filt[0] = np.array([[sigma_n**2, 0.0], [0.0, var_g]]) # Initial uncertainty
    log_likelihood = 0.0
    for t in range(1, n_steps):
        z_pred[t] = F @ z_filt[t-1] + U
        P_pred[t] = F @ P_filt[t-1] @ F.T + Q
        y_t = np.array([log_A_obs[t]])
        v_t = y_t - H @ z_pred[t]             
        S_t = H @ P_pred[t] @ H.T + R  
        S_scalar = S_t[0, 0]
        v_scalar = v_t[0]
        log_likelihood += -0.5 * np.log(2 * np.pi) - 0.5 * np.log(S_scalar) - 0.5 * (v_scalar**2 / S_scalar)        
        K_t = P_pred[t] @ H.T @ np.linalg.inv(S_t) 
        z_filt[t] = z_pred[t] + K_t @ v_t
        I_KH = np.eye(2) - K_t @ H
        P_filt[t] = I_KH @ P_pred[t] @ I_KH.T + K_t @ R @ K_t.T
    return log_likelihood

# %%
def convert_area_to_log(area_data):
    if isinstance(area_data, list):
        return [np.log(A) for A in area_data]
    else:
        return np.log(area_data)

# %%
log_A_obs = convert_area_to_log(A_obs)

# %%
L = Likelihood(log_A_obs, dt, mu, theta, sigma, sigma_n = 0.06/100)

# %%
@njit
def Likelihood(log_A_obs, dt, mu, theta, sigma, sigma_n):
    n_steps = len(log_A_obs)
    alpha = np.exp(-theta * dt)
    F = np.array([
        [1.0, (1.0 - alpha) / theta],  
        [0.0, alpha]            
    ])
    U = np.array([
        mu * dt - mu * (1.0 - alpha) / theta,
        mu * (1.0 - alpha)
    ])
    var_g = (sigma**2 / (2 * theta)) * (1 - alpha**2)
    var_X = (sigma**2 / theta**2) * (dt - (2 / theta) * (1 - alpha) + (1 / (2 * theta)) * (1 - alpha**2))
    cov_gX = (sigma**2 / (2 * theta**2)) * (1 - alpha)**2
    Q = np.array([
        [var_X, cov_gX],
        [cov_gX, var_g]
    ])
    R_scalar = sigma_n**2
    z_curr = np.array([log_A_obs[0], mu]) 
    P_curr = np.array([[R_scalar, 0.0], [0.0, var_g]])
    log_likelihood = 0.0
    for t in range(1, n_steps):
        z_pred = F @ z_curr + U
        P_pred = F @ P_curr @ F.T + Q
        v_scalar = log_A_obs[t] - z_pred[0]
        S_scalar = P_pred[0, 0] + R_scalar
        log_likelihood += -0.5 * np.log(2 * np.pi) - 0.5 * np.log(S_scalar) - 0.5 * (v_scalar**2 / S_scalar)        
        K_t = P_pred[:, 0] / S_scalar   
        z_curr = z_pred + K_t * v_scalar
        P_curr = P_pred - np.outer(K_t, P_pred[0, :])
    return log_likelihood

# %%
def log_halfnormal_sigma_from_eta(eta, scale):
    s = np.exp(eta)
    return -0.5 * (s / scale)**2 + eta 

def logprior_phi(phi, bounds=None):
    if bounds is None:
        return 0.0
    mu, eta_theta, eta_sigma, eta_n = phi
    if not (bounds['mu'][0] <= mu <= bounds['mu'][1]):
        return -np.inf
    if not (bounds['eta_theta'][0] <= eta_theta <= bounds['eta_theta'][1]):
        return -np.inf
    if not (bounds['eta_sigma'][0] <= eta_sigma <= bounds['eta_sigma'][1]):
        return -np.inf
    lp = 0.0
    lp += log_halfnormal_sigma_from_eta(eta_n, scale=0.005)
    return lp

def logpost_phi(phi, log_A_obs, dt, bounds=None):
    mu, eta_theta, eta_sigma, eta_n = phi
    lp = logprior_phi(phi, bounds=bounds)
    if not np.isfinite(lp):
        return -np.inf
    theta = np.exp(eta_theta)
    sigma = np.exp(eta_sigma)
    sigma_n = np.exp(eta_n)
    ll = Likelihood(log_A_obs, dt, mu, theta, sigma, sigma_n)
    if not np.isfinite(ll):
        return -np.inf
    return ll + lp

# %%
def mh_samples_single(log_A_obs, dt, phi0=None, prop_scales=None, bounds=None, n_steps=30000, rng=None):
    if rng is None:
        rng = np.random.RandomState(1234567)
    if phi0 is None:
        phi0 = np.array([1.0, np.log(2.0), np.log(0.240), np.log(0.0006)], float)
    else:
        phi0 = np.array(phi0, float)
    if prop_scales is None:
        prop_scales = np.array([0.02, 0.06, 0.06, 0.06], float)
    else:
        prop_scales = np.array(prop_scales, float)
    phi = phi0.copy()
    logp = logpost_phi(phi, log_A_obs, dt, bounds=bounds) 
    chain = np.zeros((n_steps, 4))
    logp_chain = np.zeros(n_steps)
    accepts = 0
    for k in range(n_steps):
        if k % 1000 == 0:
            print(f"Step {k}/{n_steps} | Current logp: {logp:.1f}")
        chain[k] = phi
        logp_chain[k] = logp
        phi_star = phi + rng.normal(0.0, prop_scales, size=4)
        logp_star = logpost_phi(phi_star, log_A_obs, dt, bounds=bounds)
        if np.isfinite(logp_star):
            log_r = logp_star - logp
            if np.log(rng.uniform()) < log_r:
                phi, logp = phi_star, logp_star
                accepts += 1              
    acc_rate = accepts / float(n_steps)
    print(f"MCMC Finished! Acceptance Rate: {acc_rate*100:.2f}%")
    return chain, logp_chain, acc_rate

# %%
bounds = {"mu": (0.5, 2.0),"eta_theta": (np.log(0.4), np.log(6.0)),
          "eta_sigma": (np.log(1e-4), np.log(1.0)),"eta_n":(np.log(0.00001), np.log(0.2)),}
prop_scales = np.array([0.02, 0.06, 0.06, 0.06], float)
phi0 = np.array([1.0, np.log(0.7), np.log(0.24), np.log(0.0006)], float)

# %%
rng_mcmc = np.random.RandomState(987654321)

# %%
chain, logp_chain, acc_rate = mh_samples_single(log_A_obs, dt, phi0=phi0,prop_scales=prop_scales,bounds=bounds, n_steps=30000, rng=rng_mcmc)
# Out:
# Step 0/30000 | Current logp: 5699.7
# Step 1000/30000 | Current logp: 5702.9
# Step 2000/30000 | Current logp: 5703.3
# Step 3000/30000 | Current logp: 5702.9
# Step 4000/30000 | Current logp: 5699.7
# Step 5000/30000 | Current logp: 5701.1
# Step 6000/30000 | Current logp: 5704.3
# Step 7000/30000 | Current logp: 5703.3
# Step 8000/30000 | Current logp: 5704.0
# Step 9000/30000 | Current logp: 5701.2
# Step 10000/30000 | Current logp: 5702.0
# Step 11000/30000 | Current logp: 5703.8
# Step 12000/30000 | Current logp: 5704.0
# Step 13000/30000 | Current logp: 5703.6
# Step 14000/30000 | Current logp: 5700.1
# Step 15000/30000 | Current logp: 5704.2
# Step 16000/30000 | Current logp: 5703.3
# Step 17000/30000 | Current logp: 5704.1
# Step 18000/30000 | Current logp: 5705.5
# Step 19000/30000 | Current logp: 5700.7
# Step 20000/30000 | Current logp: 5704.7
# Step 21000/30000 | Current logp: 5704.6
# Step 22000/30000 | Current logp: 5703.8
# Step 23000/30000 | Current logp: 5703.7
# Step 24000/30000 | Current logp: 5703.5
# Step 25000/30000 | Current logp: 5703.4
# Step 26000/30000 | Current logp: 5703.9
# Step 27000/30000 | Current logp: 5703.8
# Step 28000/30000 | Current logp: 5702.9
# Step 29000/30000 | Current logp: 5703.0
# MCMC Finished! Acceptance Rate: 31.93%

# %%
def chain_phi_to_theta(chain):
    mu = chain[:, 0]
    theta = np.exp(chain[:, 1])
    sigma = np.exp(chain[:, 2])
    sigma_n = np.exp(chain[:, 3])
    return mu, theta, sigma, sigma_n
def plot_traces(chain, true_mu, true_theta, true_sigma, true_sigma_n):
    mu, theta, sigma, sigma_n = chain_phi_to_theta(chain)
    fig, axs = plt.subplots(4, 1, figsize=(12, 8), sharex=True)
    axs[0].plot(mu, lw=0.5)
    axs[0].axhline(true_mu, color="black", linestyle="--", linewidth=1)
    axs[0].set_ylabel("mu")
    axs[1].plot(theta, lw=0.5)
    axs[1].axhline(true_theta, color="black", linestyle="--", linewidth=1)
    axs[1].set_ylabel("theta")
    axs[2].plot(sigma, lw=0.5)
    axs[2].axhline(true_sigma, color="black", linestyle="--", linewidth=1)
    axs[2].set_ylabel("sigma")
    axs[3].plot(sigma_n, lw=0.5)
    axs[3].axhline(true_sigma_n, color="black", linestyle="--", linewidth=1)
    axs[3].set_ylabel("sigma_n")
    axs[3].set_xlabel("iteration")
    plt.tight_layout()
    plt.show()

# %%
plot_traces(chain, true_mu=mu, true_theta=theta, true_sigma=sigma, true_sigma_n=0.06/100)

# %%
def mh_samples_joint_2d(log_A_obs_list, dt, phi0=None, prop_scales=None, bounds=None, n_steps=30000, rng=None, save_filename=None):    
    if rng is None:
        rng = np.random.default_rng()
    if phi0 is None:
        phi0 = np.array([1.0, np.log(2.0), np.log(0.240), np.log(0.0006)], float)
    else:
        phi0 = np.array(phi0, float)
    if prop_scales is None:
        prop_scales = np.array([0.02, 0.06, 0.06, 0.06], float)
    else:
        prop_scales = np.array(prop_scales, float)
    def compute_joint_logp(phi_eval):
        lp = logprior_phi(phi_eval, bounds=bounds)
        if not np.isfinite(lp):
            return -np.inf
        mu, eta_theta, eta_sigma, eta_n = phi_eval
        theta = np.exp(eta_theta)
        sigma = np.exp(eta_sigma)
        sigma_n = np.exp(eta_n)
        total_ll = 0.0
        for log_A_obs in log_A_obs_list:
            ll = Likelihood(log_A_obs, dt, mu, theta, sigma, sigma_n)
            if not np.isfinite(ll):
                return -np.inf
            total_ll += ll
        return total_ll + lp
    phi = phi0.copy()
    logp = compute_joint_logp(phi)
    chain = np.zeros((n_steps, 4))
    logp_chain = np.zeros(n_steps)
    accepts = 0
    pbar = tqdm(range(n_steps), desc="Joint 2D MCMC")
    for k in pbar:
        if (k + 1) % 1000 == 0:
            pbar.set_postfix({'Log-P': f"{logp:.2f}"})
        chain[k] = phi
        logp_chain[k] = logp
        phi_star = phi + rng.normal(0.0, prop_scales, size=4)
        logp_star = compute_joint_logp(phi_star)
        if np.isfinite(logp_star):
            log_r = logp_star - logp
            if np.log(rng.uniform()) < log_r:
                phi, logp = phi_star, logp_star
                accepts += 1             
    acc_rate = accepts / float(n_steps)
    print(f"Finished! Acceptance rate: {acc_rate:.3f}")
    if save_filename is not None:
        np.savez(save_filename, chain=chain, logp_chain=logp_chain, acc_rate=acc_rate)
        print(f"Success! Joint MCMC data safely saved to '{save_filename}'.")
        
    return chain, logp_chain, acc_rate

# %%
log_A_obs_list = convert_area_to_log(A_obs_list)

# %%
bounds = {"mu": (0.5, 2.0),"eta_theta": (np.log(0.4), np.log(6.0)),
          "eta_sigma": (np.log(1e-4), np.log(1.0)),"eta_n":(np.log(0.00001), np.log(0.2)),}
prop_scales = np.array([0.01, 0.025, 0.025, 0.025], float)
phi0 = np.array([1.0, np.log(0.7), np.log(0.24), np.log(0.0006)], float)

# %%
chain_multiple, logp_multiple, acc_rate_multiple = mh_samples_joint_2d(log_A_obs_list=log_A_obs_list, dt=dt, phi0=phi0, prop_scales=prop_scales, bounds=bounds, n_steps=50000, rng=rng_mcmc, save_filename="6 2 pct noise Joint mcmc.npz")
# Out:
# Joint 2D MCMC:   0%|          | 0/50000 [00:00<?, ?it/s]
# Finished! Acceptance rate: 0.235
# Success! Joint MCMC data safely saved to '6 2 pct noise Joint mcmc.npz'.

# %%
plot_traces(chain_multiple, true_mu=mu, true_theta=theta, true_sigma=sigma, true_sigma_n=0.06/100)

# %%
def computing_single_chains(Y, dt, phi0=None, bounds=None, prop_scales=None, n_steps=30000, rng=None, save_filename="single_mcmc_results.npz"):
    all_chains = []
    all_acc_rates = []
    all_logp_chains = [] 
    N_traj = len(Y)
    for i in tqdm(range(N_traj), desc="Computing Single Chains"):
        chain, logp_chain, acc_rate = mh_samples_single(Y[i], dt, phi0=phi0, bounds=bounds, prop_scales=prop_scales, n_steps=n_steps, rng=rng)
        all_chains.append(chain)
        all_logp_chains.append(logp_chain)
        all_acc_rates.append(acc_rate)
    all_chains_arr = np.array(all_chains)
    all_logp_chains_arr = np.array(all_logp_chains)
    all_acc_rates_arr = np.array(all_acc_rates)
    np.savez(save_filename, chain_single=all_chains_arr, logp_single=all_logp_chains_arr, acc_rate_single=all_acc_rates_arr)
    print(f"Success! {N_traj} independent MCMC chains safely saved to '{save_filename}'.")
    return all_chains_arr

# %%
chain_single = computing_single_chains(log_A_obs_list, dt, phi0=phi0, bounds=bounds, prop_scales=prop_scales, n_steps=50000, rng=rng_mcmc, save_filename="2 area single_mcmc_results.npz")
# Out:
# Computing Single Chains:   0%|          | 0/10 [00:00<?, ?it/s]
# Step 0/50000 | Current logp: 5699.7
# Step 1000/50000 | Current logp: 5701.7
# Step 2000/50000 | Current logp: 5703.2
# Step 3000/50000 | Current logp: 5703.0
# Step 4000/50000 | Current logp: 5702.7
# Step 5000/50000 | Current logp: 5703.7
# Step 6000/50000 | Current logp: 5704.9
# Step 7000/50000 | Current logp: 5703.9
# Step 8000/50000 | Current logp: 5701.1
# Step 9000/50000 | Current logp: 5702.2
# Step 10000/50000 | Current logp: 5701.6
# Step 11000/50000 | Current logp: 5703.6
# Step 12000/50000 | Current logp: 5702.0
# Step 13000/50000 | Current logp: 5703.5
# Step 14000/50000 | Current logp: 5703.0
# Step 15000/50000 | Current logp: 5704.1
# Step 16000/50000 | Current logp: 5703.9
# Step 17000/50000 | Current logp: 5703.4
# Step 18000/50000 | Current logp: 5703.8
# Step 19000/50000 | Current logp: 5704.0
# Step 20000/50000 | Current logp: 5702.2
# Step 21000/50000 | Current logp: 5703.3
# Step 22000/50000 | Current logp: 5703.1
# Step 23000/50000 | Current logp: 5704.9
# Step 24000/50000 | Current logp: 5704.3
# Step 25000/50000 | Current logp: 5703.6
# Step 26000/50000 | Current logp: 5704.4
# Step 27000/50000 | Current logp: 5704.5
# Step 28000/50000 | Current logp: 5705.6
# Step 29000/50000 | Current logp: 5703.6
# Step 30000/50000 | Current logp: 5700.6
# Step 31000/50000 | Current logp: 5703.5
# Step 32000/50000 | Current logp: 5704.4
# Step 33000/50000 | Current logp: 5704.1
# Step 34000/50000 | Current logp: 5696.6
# Step 35000/50000 | Current logp: 5704.5
# Step 36000/50000 | Current logp: 5705.1
# Step 37000/50000 | Current logp: 5703.1
# Step 38000/50000 | Current logp: 5703.6
# Step 39000/50000 | Current logp: 5703.0
# Step 40000/50000 | Current logp: 5701.9
# Step 41000/50000 | Current logp: 5703.3
# Step 42000/50000 | Current logp: 5704.4
# Step 43000/50000 | Current logp: 5703.5
# Step 44000/50000 | Current logp: 5698.8
# Step 45000/50000 | Current logp: 5703.3
# Step 46000/50000 | Current logp: 5705.0
# Step 47000/50000 | Current logp: 5702.9
# Step 48000/50000 | Current logp: 5705.1
# Step 49000/50000 | Current logp: 5703.8
# MCMC Finished! Acceptance Rate: 62.47%
# Step 0/50000 | Current logp: 5672.4
# Step 1000/50000 | Current logp: 5679.5
# Step 2000/50000 | Current logp: 5676.8
# Step 3000/50000 | Current logp: 5679.5
# Step 4000/50000 | Current logp: 5680.3
# Step 5000/50000 | Current logp: 5681.0
# Step 6000/50000 | Current logp: 5680.1
# Step 7000/50000 | Current logp: 5678.1
# Step 8000/50000 | Current logp: 5680.8
# Step 9000/50000 | Current logp: 5679.6
# Step 10000/50000 | Current logp: 5679.4
# Step 11000/50000 | Current logp: 5678.3
# Step 12000/50000 | Current logp: 5677.0
# Step 13000/50000 | Current logp: 5679.7
# Step 14000/50000 | Current logp: 5675.9
# Step 15000/50000 | Current logp: 5680.2
# Step 16000/50000 | Current logp: 5680.6
# Step 17000/50000 | Current logp: 5679.7
# Step 18000/50000 | Current logp: 5680.8
# Step 19000/50000 | Current logp: 5679.6
# Step 20000/50000 | Current logp: 5679.9
# Step 21000/50000 | Current logp: 5680.0
# Step 22000/50000 | Current logp: 5678.7
# Step 23000/50000 | Current logp: 5676.8
# Step 24000/50000 | Current logp: 5678.0
# Step 25000/50000 | Current logp: 5680.5
# Step 26000/50000 | Current logp: 5680.9
# Step 27000/50000 | Current logp: 5680.5
# Step 28000/50000 | Current logp: 5680.5
# Step 29000/50000 | Current logp: 5679.0
# Step 30000/50000 | Current logp: 5680.7
# Step 31000/50000 | Current logp: 5678.9
# Step 32000/50000 | Current logp: 5678.7
# Step 33000/50000 | Current logp: 5680.8
# Step 34000/50000 | Current logp: 5680.5
# Step 35000/50000 | Current logp: 5681.1
# Step 36000/50000 | Current logp: 5679.4
# Step 37000/50000 | Current logp: 5678.6
# Step 38000/50000 | Current logp: 5680.5
# Step 39000/50000 | Current logp: 5680.9
# Step 40000/50000 | Current logp: 5680.9
# Step 41000/50000 | Current logp: 5678.2
# Step 42000/50000 | Current logp: 5680.6
# Step 43000/50000 | Current logp: 5678.7
# Step 44000/50000 | Current logp: 5679.7
# Step 45000/50000 | Current logp: 5680.5
# Step 46000/50000 | Current logp: 5681.2
# Step 47000/50000 | Current logp: 5680.1
# Step 48000/50000 | Current logp: 5679.4
# Step 49000/50000 | Current logp: 5680.2
# MCMC Finished! Acceptance Rate: 62.58%
# Step 0/50000 | Current logp: 5668.4
# Step 1000/50000 | Current logp: 5672.9
# Step 2000/50000 | Current logp: 5674.9
# Step 3000/50000 | Current logp: 5673.0
# Step 4000/50000 | Current logp: 5670.8
# Step 5000/50000 | Current logp: 5672.8
# Step 6000/50000 | Current logp: 5674.0
# Step 7000/50000 | Current logp: 5674.7
# Step 8000/50000 | Current logp: 5673.8
# Step 9000/50000 | Current logp: 5674.1
# Step 10000/50000 | Current logp: 5675.1
# Step 11000/50000 | Current logp: 5673.3
# Step 12000/50000 | Current logp: 5674.6
# Step 13000/50000 | Current logp: 5675.3
# Step 14000/50000 | Current logp: 5674.8
# Step 15000/50000 | Current logp: 5674.5
# Step 16000/50000 | Current logp: 5675.0
# Step 17000/50000 | Current logp: 5668.1
# Step 18000/50000 | Current logp: 5672.5
# Step 19000/50000 | Current logp: 5673.9
# Step 20000/50000 | Current logp: 5674.7
# Step 21000/50000 | Current logp: 5674.7
# Step 22000/50000 | Current logp: 5673.9
# Step 23000/50000 | Current logp: 5672.2
# Step 24000/50000 | Current logp: 5674.6
# Step 25000/50000 | Current logp: 5673.6
# Step 26000/50000 | Current logp: 5674.9
# Step 27000/50000 | Current logp: 5675.2
# Step 28000/50000 | Current logp: 5674.2
# Step 29000/50000 | Current logp: 5675.5
# Step 30000/50000 | Current logp: 5672.2
# Step 31000/50000 | Current logp: 5673.3
# Step 32000/50000 | Current logp: 5673.7
# Step 33000/50000 | Current logp: 5673.4
# Step 34000/50000 | Current logp: 5673.6
# Step 35000/50000 | Current logp: 5674.1
# Step 36000/50000 | Current logp: 5674.9
# Step 37000/50000 | Current logp: 5674.1
# Step 38000/50000 | Current logp: 5674.1
# Step 39000/50000 | Current logp: 5675.0
# Step 40000/50000 | Current logp: 5674.0
# Step 41000/50000 | Current logp: 5674.8
# Step 42000/50000 | Current logp: 5673.1
# Step 43000/50000 | Current logp: 5674.2
# Step 44000/50000 | Current logp: 5675.4
# Step 45000/50000 | Current logp: 5672.2
# Step 46000/50000 | Current logp: 5674.2
# Step 47000/50000 | Current logp: 5674.3
# Step 48000/50000 | Current logp: 5674.6
# Step 49000/50000 | Current logp: 5675.1
# MCMC Finished! Acceptance Rate: 63.76%
# Step 0/50000 | Current logp: 5691.2
# Step 1000/50000 | Current logp: 5694.8
# Step 2000/50000 | Current logp: 5693.1
# Step 3000/50000 | Current logp: 5694.0
# Step 4000/50000 | Current logp: 5691.5
# Step 5000/50000 | Current logp: 5694.0
# Step 6000/50000 | Current logp: 5694.6
# Step 7000/50000 | Current logp: 5691.5
# Step 8000/50000 | Current logp: 5694.7
# Step 9000/50000 | Current logp: 5694.8
# Step 10000/50000 | Current logp: 5695.0
# Step 11000/50000 | Current logp: 5694.4
# Step 12000/50000 | Current logp: 5694.5
# Step 13000/50000 | Current logp: 5695.1
# Step 14000/50000 | Current logp: 5694.0
# Step 15000/50000 | Current logp: 5693.9
# Step 16000/50000 | Current logp: 5693.0
# Step 17000/50000 | Current logp: 5694.5
# Step 18000/50000 | Current logp: 5693.4
# Step 19000/50000 | Current logp: 5694.7
# Step 20000/50000 | Current logp: 5693.1
# Step 21000/50000 | Current logp: 5694.5
# Step 22000/50000 | Current logp: 5694.8
# Step 23000/50000 | Current logp: 5691.6
# Step 24000/50000 | Current logp: 5695.6
# Step 25000/50000 | Current logp: 5693.5
# Step 26000/50000 | Current logp: 5694.8
# Step 27000/50000 | Current logp: 5693.2
# Step 28000/50000 | Current logp: 5694.8
# Step 29000/50000 | Current logp: 5693.8
# Step 30000/50000 | Current logp: 5695.7
# Step 31000/50000 | Current logp: 5695.0
# Step 32000/50000 | Current logp: 5693.1
# Step 33000/50000 | Current logp: 5695.3
# Step 34000/50000 | Current logp: 5690.5
# Step 35000/50000 | Current logp: 5692.7
# Step 36000/50000 | Current logp: 5694.6
# Step 37000/50000 | Current logp: 5690.8
# Step 38000/50000 | Current logp: 5693.6
# Step 39000/50000 | Current logp: 5694.4
# Step 40000/50000 | Current logp: 5693.8
# Step 41000/50000 | Current logp: 5693.1
# Step 42000/50000 | Current logp: 5694.1
# Step 43000/50000 | Current logp: 5694.4
# Step 44000/50000 | Current logp: 5693.9
# Step 45000/50000 | Current logp: 5694.8
# Step 46000/50000 | Current logp: 5693.8
# Step 47000/50000 | Current logp: 5692.6
# Step 48000/50000 | Current logp: 5694.2
# Step 49000/50000 | Current logp: 5689.6
# MCMC Finished! Acceptance Rate: 63.30%
# Step 0/50000 | Current logp: 5685.9
# Step 1000/50000 | Current logp: 5694.2
# Step 2000/50000 | Current logp: 5695.0
# Step 3000/50000 | Current logp: 5695.3
# Step 4000/50000 | Current logp: 5694.3
# Step 5000/50000 | Current logp: 5694.5
# Step 6000/50000 | Current logp: 5694.7
# Step 7000/50000 | Current logp: 5692.9
# Step 8000/50000 | Current logp: 5695.3
# Step 9000/50000 | Current logp: 5694.7
# Step 10000/50000 | Current logp: 5692.5
# Step 11000/50000 | Current logp: 5691.7
# Step 12000/50000 | Current logp: 5693.5
# Step 13000/50000 | Current logp: 5694.7
# Step 14000/50000 | Current logp: 5695.1
# Step 15000/50000 | Current logp: 5695.2
# Step 16000/50000 | Current logp: 5694.4
# Step 17000/50000 | Current logp: 5696.1
# Step 18000/50000 | Current logp: 5693.8
# Step 19000/50000 | Current logp: 5694.6
# Step 20000/50000 | Current logp: 5695.3
# Step 21000/50000 | Current logp: 5694.5
# Step 22000/50000 | Current logp: 5695.1
# Step 23000/50000 | Current logp: 5695.4
# Step 24000/50000 | Current logp: 5693.5
# Step 25000/50000 | Current logp: 5694.1
# Step 26000/50000 | Current logp: 5694.1
# Step 27000/50000 | Current logp: 5694.0
# Step 28000/50000 | Current logp: 5693.7
# Step 29000/50000 | Current logp: 5695.3
# Step 30000/50000 | Current logp: 5695.1
# Step 31000/50000 | Current logp: 5694.6
# Step 32000/50000 | Current logp: 5693.7
# Step 33000/50000 | Current logp: 5695.5
# Step 34000/50000 | Current logp: 5693.0
# Step 35000/50000 | Current logp: 5695.1
# Step 36000/50000 | Current logp: 5694.1
# Step 37000/50000 | Current logp: 5695.9
# Step 38000/50000 | Current logp: 5695.6
# Step 39000/50000 | Current logp: 5694.2
# Step 40000/50000 | Current logp: 5694.0
# Step 41000/50000 | Current logp: 5694.2
# Step 42000/50000 | Current logp: 5694.2
# Step 43000/50000 | Current logp: 5695.1
# Step 44000/50000 | Current logp: 5694.7
# Step 45000/50000 | Current logp: 5694.8
# Step 46000/50000 | Current logp: 5694.2
# Step 47000/50000 | Current logp: 5695.0
# Step 48000/50000 | Current logp: 5695.1
# Step 49000/50000 | Current logp: 5694.6
# MCMC Finished! Acceptance Rate: 63.39%
# Step 0/50000 | Current logp: 5690.4
# Step 1000/50000 | Current logp: 5694.6
# Step 2000/50000 | Current logp: 5698.4
# Step 3000/50000 | Current logp: 5699.0
# Step 4000/50000 | Current logp: 5698.2
# Step 5000/50000 | Current logp: 5697.5
# Step 6000/50000 | Current logp: 5697.6
# Step 7000/50000 | Current logp: 5697.3
# Step 8000/50000 | Current logp: 5699.2
# Step 9000/50000 | Current logp: 5698.6
# Step 10000/50000 | Current logp: 5699.3
# Step 11000/50000 | Current logp: 5698.2
# Step 12000/50000 | Current logp: 5697.2
# Step 13000/50000 | Current logp: 5697.6
# Step 14000/50000 | Current logp: 5699.4
# Step 15000/50000 | Current logp: 5696.5
# Step 16000/50000 | Current logp: 5697.9
# Step 17000/50000 | Current logp: 5695.1
# Step 18000/50000 | Current logp: 5696.4
# Step 19000/50000 | Current logp: 5697.4
# Step 20000/50000 | Current logp: 5699.1
# Step 21000/50000 | Current logp: 5699.3
# Step 22000/50000 | Current logp: 5698.9
# Step 23000/50000 | Current logp: 5699.3
# Step 24000/50000 | Current logp: 5697.5
# Step 25000/50000 | Current logp: 5697.4
# Step 26000/50000 | Current logp: 5696.2
# Step 27000/50000 | Current logp: 5697.7
# Step 28000/50000 | Current logp: 5697.8
# Step 29000/50000 | Current logp: 5697.0
# Step 30000/50000 | Current logp: 5699.2
# Step 31000/50000 | Current logp: 5696.5
# Step 32000/50000 | Current logp: 5698.2
# Step 33000/50000 | Current logp: 5695.5
# Step 34000/50000 | Current logp: 5698.9
# Step 35000/50000 | Current logp: 5696.6
# Step 36000/50000 | Current logp: 5696.9
# Step 37000/50000 | Current logp: 5699.5
# Step 38000/50000 | Current logp: 5699.1
# Step 39000/50000 | Current logp: 5699.0
# Step 40000/50000 | Current logp: 5698.3
# Step 41000/50000 | Current logp: 5696.1
# Step 42000/50000 | Current logp: 5694.0
# Step 43000/50000 | Current logp: 5697.6
# Step 44000/50000 | Current logp: 5698.1
# Step 45000/50000 | Current logp: 5698.3
# Step 46000/50000 | Current logp: 5698.4
# Step 47000/50000 | Current logp: 5699.6
# Step 48000/50000 | Current logp: 5698.2
# Step 49000/50000 | Current logp: 5698.6
# MCMC Finished! Acceptance Rate: 63.26%
# Step 0/50000 | Current logp: 5619.3
# Step 1000/50000 | Current logp: 5680.6
# Step 2000/50000 | Current logp: 5680.0
# Step 3000/50000 | Current logp: 5680.0
# Step 4000/50000 | Current logp: 5679.2
# Step 5000/50000 | Current logp: 5676.1
# Step 6000/50000 | Current logp: 5679.3
# Step 7000/50000 | Current logp: 5680.1
# Step 8000/50000 | Current logp: 5676.1
# Step 9000/50000 | Current logp: 5680.3
# Step 10000/50000 | Current logp: 5675.6
# Step 11000/50000 | Current logp: 5679.5
# Step 12000/50000 | Current logp: 5679.9
# Step 13000/50000 | Current logp: 5679.6
# Step 14000/50000 | Current logp: 5680.0
# Step 15000/50000 | Current logp: 5679.8
# Step 16000/50000 | Current logp: 5672.3
# Step 17000/50000 | Current logp: 5678.9
# Step 18000/50000 | Current logp: 5679.6
# Step 19000/50000 | Current logp: 5680.0
# Step 20000/50000 | Current logp: 5680.2
# Step 21000/50000 | Current logp: 5679.7
# Step 22000/50000 | Current logp: 5678.5
# Step 23000/50000 | Current logp: 5679.5
# Step 24000/50000 | Current logp: 5678.5
# Step 25000/50000 | Current logp: 5679.3
# Step 26000/50000 | Current logp: 5678.5
# Step 27000/50000 | Current logp: 5674.1
# Step 28000/50000 | Current logp: 5679.7
# Step 29000/50000 | Current logp: 5679.8
# Step 30000/50000 | Current logp: 5680.0
# Step 31000/50000 | Current logp: 5679.9
# Step 32000/50000 | Current logp: 5677.1
# Step 33000/50000 | Current logp: 5679.3
# Step 34000/50000 | Current logp: 5677.5
# Step 35000/50000 | Current logp: 5679.7
# Step 36000/50000 | Current logp: 5677.5
# Step 37000/50000 | Current logp: 5678.6
# Step 38000/50000 | Current logp: 5679.5
# Step 39000/50000 | Current logp: 5680.3
# Step 40000/50000 | Current logp: 5680.1
# Step 41000/50000 | Current logp: 5678.2
# Step 42000/50000 | Current logp: 5678.8
# Step 43000/50000 | Current logp: 5680.0
# Step 44000/50000 | Current logp: 5679.8
# Step 45000/50000 | Current logp: 5680.8
# Step 46000/50000 | Current logp: 5680.5
# Step 47000/50000 | Current logp: 5679.5
# Step 48000/50000 | Current logp: 5678.5
# Step 49000/50000 | Current logp: 5676.0
# MCMC Finished! Acceptance Rate: 62.67%
# Step 0/50000 | Current logp: 5727.9
# Step 1000/50000 | Current logp: 5740.8
# Step 2000/50000 | Current logp: 5744.2
# Step 3000/50000 | Current logp: 5741.6
# Step 4000/50000 | Current logp: 5744.4
# Step 5000/50000 | Current logp: 5744.5
# Step 6000/50000 | Current logp: 5742.8
# Step 7000/50000 | Current logp: 5745.0
# Step 8000/50000 | Current logp: 5744.0
# Step 9000/50000 | Current logp: 5745.2
# Step 10000/50000 | Current logp: 5744.9
# Step 11000/50000 | Current logp: 5745.7
# Step 12000/50000 | Current logp: 5745.2
# Step 13000/50000 | Current logp: 5742.9
# Step 14000/50000 | Current logp: 5745.9
# Step 15000/50000 | Current logp: 5745.8
# Step 16000/50000 | Current logp: 5743.7
# Step 17000/50000 | Current logp: 5745.4
# Step 18000/50000 | Current logp: 5744.8
# Step 19000/50000 | Current logp: 5745.3
# Step 20000/50000 | Current logp: 5744.0
# Step 21000/50000 | Current logp: 5744.3
# Step 22000/50000 | Current logp: 5744.4
# Step 23000/50000 | Current logp: 5745.5
# Step 24000/50000 | Current logp: 5744.3
# Step 25000/50000 | Current logp: 5743.6
# Step 26000/50000 | Current logp: 5744.0
# Step 27000/50000 | Current logp: 5741.4
# Step 28000/50000 | Current logp: 5745.2
# Step 29000/50000 | Current logp: 5744.5
# Step 30000/50000 | Current logp: 5743.9
# Step 31000/50000 | Current logp: 5744.9
# Step 32000/50000 | Current logp: 5743.7
# Step 33000/50000 | Current logp: 5746.1
# Step 34000/50000 | Current logp: 5743.8
# Step 35000/50000 | Current logp: 5743.9
# Step 36000/50000 | Current logp: 5746.2
# Step 37000/50000 | Current logp: 5745.2
# Step 38000/50000 | Current logp: 5746.4
# Step 39000/50000 | Current logp: 5744.8
# Step 40000/50000 | Current logp: 5746.2
# Step 41000/50000 | Current logp: 5746.0
# Step 42000/50000 | Current logp: 5744.9
# Step 43000/50000 | Current logp: 5745.9
# Step 44000/50000 | Current logp: 5742.8
# Step 45000/50000 | Current logp: 5744.8
# Step 46000/50000 | Current logp: 5745.0
# Step 47000/50000 | Current logp: 5744.8
# Step 48000/50000 | Current logp: 5745.5
# Step 49000/50000 | Current logp: 5743.8
# MCMC Finished! Acceptance Rate: 63.10%
# Step 0/50000 | Current logp: 5703.9
# Step 1000/50000 | Current logp: 5703.3
# Step 2000/50000 | Current logp: 5703.9
# Step 3000/50000 | Current logp: 5706.9
# Step 4000/50000 | Current logp: 5706.1
# Step 5000/50000 | Current logp: 5708.1
# Step 6000/50000 | Current logp: 5707.4
# Step 7000/50000 | Current logp: 5705.5
# Step 8000/50000 | Current logp: 5708.1
# Step 9000/50000 | Current logp: 5707.5
# Step 10000/50000 | Current logp: 5707.3
# Step 11000/50000 | Current logp: 5708.1
# Step 12000/50000 | Current logp: 5707.5
# Step 13000/50000 | Current logp: 5706.2
# Step 14000/50000 | Current logp: 5707.2
# Step 15000/50000 | Current logp: 5705.6
# Step 16000/50000 | Current logp: 5708.0
# Step 17000/50000 | Current logp: 5708.1
# Step 18000/50000 | Current logp: 5708.1
# Step 19000/50000 | Current logp: 5706.6
# Step 20000/50000 | Current logp: 5707.4
# Step 21000/50000 | Current logp: 5706.5
# Step 22000/50000 | Current logp: 5705.6
# Step 23000/50000 | Current logp: 5705.6
# Step 24000/50000 | Current logp: 5706.9
# Step 25000/50000 | Current logp: 5703.7
# Step 26000/50000 | Current logp: 5707.4
# Step 27000/50000 | Current logp: 5705.8
# Step 28000/50000 | Current logp: 5708.1
# Step 29000/50000 | Current logp: 5700.5
# Step 30000/50000 | Current logp: 5707.7
# Step 31000/50000 | Current logp: 5708.2
# Step 32000/50000 | Current logp: 5707.6
# Step 33000/50000 | Current logp: 5705.9
# Step 34000/50000 | Current logp: 5707.2
# Step 35000/50000 | Current logp: 5706.9
# Step 36000/50000 | Current logp: 5707.5
# Step 37000/50000 | Current logp: 5706.5
# Step 38000/50000 | Current logp: 5705.7
# Step 39000/50000 | Current logp: 5707.6
# Step 40000/50000 | Current logp: 5704.7
# Step 41000/50000 | Current logp: 5704.4
# Step 42000/50000 | Current logp: 5705.5
# Step 43000/50000 | Current logp: 5707.5
# Step 44000/50000 | Current logp: 5701.9
# Step 45000/50000 | Current logp: 5706.3
# Step 46000/50000 | Current logp: 5703.2
# Step 47000/50000 | Current logp: 5706.7
# Step 48000/50000 | Current logp: 5707.4
# Step 49000/50000 | Current logp: 5705.6
# MCMC Finished! Acceptance Rate: 63.55%
# Step 0/50000 | Current logp: 5681.8
# Step 1000/50000 | Current logp: 5689.0
# Step 2000/50000 | Current logp: 5685.5
# Step 3000/50000 | Current logp: 5688.7
# Step 4000/50000 | Current logp: 5688.6
# Step 5000/50000 | Current logp: 5688.5
# Step 6000/50000 | Current logp: 5686.0
# Step 7000/50000 | Current logp: 5686.2
# Step 8000/50000 | Current logp: 5688.5
# Step 9000/50000 | Current logp: 5686.2
# Step 10000/50000 | Current logp: 5688.8
# Step 11000/50000 | Current logp: 5687.1
# Step 12000/50000 | Current logp: 5686.6
# Step 13000/50000 | Current logp: 5683.8
# Step 14000/50000 | Current logp: 5688.2
# Step 15000/50000 | Current logp: 5685.7
# Step 16000/50000 | Current logp: 5686.4
# Step 17000/50000 | Current logp: 5687.8
# Step 18000/50000 | Current logp: 5688.2
# Step 19000/50000 | Current logp: 5687.5
# Step 20000/50000 | Current logp: 5687.6
# Step 21000/50000 | Current logp: 5684.8
# Step 22000/50000 | Current logp: 5684.7
# Step 23000/50000 | Current logp: 5687.5
# Step 24000/50000 | Current logp: 5687.4
# Step 25000/50000 | Current logp: 5688.4
# Step 26000/50000 | Current logp: 5688.6
# Step 27000/50000 | Current logp: 5688.1
# Step 28000/50000 | Current logp: 5684.3
# Step 29000/50000 | Current logp: 5687.9
# Step 30000/50000 | Current logp: 5688.2
# Step 31000/50000 | Current logp: 5686.3
# Step 32000/50000 | Current logp: 5687.8
# Step 33000/50000 | Current logp: 5687.1
# Step 34000/50000 | Current logp: 5688.2
# Step 35000/50000 | Current logp: 5685.2
# Step 36000/50000 | Current logp: 5688.2
# Step 37000/50000 | Current logp: 5689.0
# Step 38000/50000 | Current logp: 5688.5
# Step 39000/50000 | Current logp: 5688.6
# Step 40000/50000 | Current logp: 5688.4
# Step 41000/50000 | Current logp: 5688.0
# Step 42000/50000 | Current logp: 5688.0
# Step 43000/50000 | Current logp: 5687.4
# Step 44000/50000 | Current logp: 5687.1
# Step 45000/50000 | Current logp: 5689.0
# Step 46000/50000 | Current logp: 5684.2
# Step 47000/50000 | Current logp: 5688.3
# Step 48000/50000 | Current logp: 5687.1
# Step 49000/50000 | Current logp: 5687.4
# MCMC Finished! Acceptance Rate: 63.65%
# Success! 10 independent MCMC chains safely saved to '2 area single_mcmc_results.npz'.

# %%
@njit
def inv_2x2(M):
    det = M[0,0]*M[1,1] - M[0,1]*M[1,0]
    return np.array([
        [ M[1,1]/det, -M[0,1]/det],
        [-M[1,0]/det,  M[0,0]/det]
    ])
@njit
def matmul_2x2(A, B):
    return np.array([
        [A[0,0]*B[0,0] + A[0,1]*B[1,0], A[0,0]*B[0,1] + A[0,1]*B[1,1]],
        [A[1,0]*B[0,0] + A[1,1]*B[1,0], A[1,0]*B[0,1] + A[1,1]*B[1,1]]
    ])
@njit
def matvec_2x2(A, v):
    return np.array([
        A[0,0]*v[0] + A[0,1]*v[1],
        A[1,0]*v[0] + A[1,1]*v[1]
    ])
@njit
def transpose_2x2(A):
    return np.array([[A[0,0], A[1,0]], [A[0,1], A[1,1]]])
@njit
def KalmanSmoother_2D_Fast(log_A_obs, dt, mu, theta, sigma, sigma_n):
    N = len(log_A_obs)
    alpha = np.exp(-theta * dt)
    
    F = np.array([
        [1.0, (1.0 - alpha) / theta],  
        [0.0, alpha]            
    ])
    F_T = transpose_2x2(F)
    
    U = np.array([
        mu * dt - mu * (1.0 - alpha) / theta,
        mu * (1.0 - alpha)
    ])
    
    var_g = (sigma**2 / (2 * theta)) * (1 - alpha**2)
    var_X = (sigma**2 / theta**2) * (dt - (2 / theta) * (1 - alpha) + (1 / (2 * theta)) * (1 - alpha**2))
    cov_gX = (sigma**2 / (2 * theta**2)) * (1 - alpha)**2
    Q = np.array([
        [var_X, cov_gX],
        [cov_gX, var_g]
    ])
    
    R_scalar = sigma_n**2
    
    z_filt = np.zeros((N, 2))
    P_filt = np.zeros((N, 2, 2))
    z_pred = np.zeros((N, 2))
    P_pred = np.zeros((N, 2, 2))
    
    z_filt[0] = np.array([log_A_obs[0], mu]) 
    P_filt[0] = np.array([[R_scalar, 0.0], [0.0, var_g]])
    
    for t in range(1, N):
        z_pred[t] = matvec_2x2(F, z_filt[t-1]) + U
        P_pred[t] = matmul_2x2(matmul_2x2(F, P_filt[t-1]), F_T) + Q
        v_scalar = log_A_obs[t] - z_pred[t, 0]
        S_scalar = P_pred[t, 0, 0] + R_scalar
        
        K_t = np.array([P_pred[t, 0, 0] / S_scalar, P_pred[t, 1, 0] / S_scalar])
        
        z_filt[t] = z_pred[t] + K_t * v_scalar
        
        K_HP = np.array([
            [K_t[0]*P_pred[t, 0, 0], K_t[0]*P_pred[t, 0, 1]],
            [K_t[1]*P_pred[t, 0, 0], K_t[1]*P_pred[t, 0, 1]]
        ])
        P_filt[t] = P_pred[t] - K_HP

    z_smooth = np.zeros((N, 2))
    P_smooth = np.zeros((N, 2, 2))
    
    z_smooth[N-1] = z_filt[N-1]
    P_smooth[N-1] = P_filt[N-1]
    
    for t in range(N-2, -1, -1):
        inv_P_pred = inv_2x2(P_pred[t+1])
        C_t = matmul_2x2(matmul_2x2(P_filt[t], F_T), inv_P_pred)

        diff_z = z_smooth[t+1] - z_pred[t+1]
        z_smooth[t] = z_filt[t] + matvec_2x2(C_t, diff_z)

        diff_P = P_smooth[t+1] - P_pred[t+1]
        C_t_T = transpose_2x2(C_t)
        P_smooth[t] = P_filt[t] + matmul_2x2(matmul_2x2(C_t, diff_P), C_t_T)
        
    return z_smooth, P_smooth

# %%
def rts_smoother_2d(chain, log_A_obs, dt, n_samples=1000, burn_in=5000):
    N = len(log_A_obs)
    valid_chain = chain[burn_in:]
    indices = np.random.choice(len(valid_chain), size=n_samples, replace=False)
    selected_samples = valid_chain[indices]
    cloud_trajectories = np.zeros((n_samples, N))
    
    for i, phi in enumerate(selected_samples):
        mu_val = phi[0]
        theta_val = np.exp(phi[1])
        sigma_val = np.exp(phi[2])
        sigma_n_val = np.exp(phi[3])
        z_smooth, P_smooth = KalmanSmoother_2D_Fast(
            log_A_obs, dt, mu=mu_val, theta=theta_val, sigma=sigma_val, sigma_n=sigma_n_val
        )
        cloud_trajectories[i, :] = z_smooth[:, 1]
    posterior_mean = np.mean(cloud_trajectories, axis=0)
    
    return posterior_mean

# %%
def plot_cloud_grid_joint(chain, log_A_obs_list, true_G, dt, rows, cols, n_samples=100, zoom_t_start=3.0, zoom_t_end=3.5):
    N_traj = len(log_A_obs_list)
    if rows * cols < N_traj:
        raise ValueError(f"A {rows}x{cols} grid only holds {rows*cols} plots, but you have {N_traj}.")
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 4), squeeze=False)
    axes = axes.flatten()
    t = np.arange(len(log_A_obs_list[0])) * dt
    idx_start = int(zoom_t_start / dt)
    idx_end = int(zoom_t_end / dt)
    burn_in = 5000
    valid_chain = chain[burn_in:]
    indices = np.random.choice(len(valid_chain), size=n_samples, replace=False)
    selected_samples = valid_chain[indices]
    for i in tqdm(range(rows * cols), desc="Generating Joint MCMC Clouds"):
        ax = axes[i]
        if i < N_traj:
            y = log_A_obs_list[i]
            true_g = true_G[i]
            
            cloud_trajectories = np.zeros((n_samples, len(y)))
            
            for j, phi in enumerate(selected_samples):
                mu_s, eta_theta_s, eta_sigma_s, eta_n_s = phi
                theta_s, sigma_s, sigma_n_s = np.exp(eta_theta_s), np.exp(eta_sigma_s), np.exp(eta_n_s)
                
                m_smooth, P_smooth = KalmanSmoother_2D_Fast(y, dt, mu_s, theta_s, sigma_s, sigma_n_s)
                cloud_trajectories[j, :] = m_smooth[:, 1]    
            posterior_mean = np.mean(cloud_trajectories, axis=0) 
            ax.plot(t, cloud_trajectories.T, color='gray', alpha=0.1, lw=1)
            ax.plot(t, posterior_mean, color='blue', lw=2, label='Posterior Mean') 
            if true_G is not None:
                ax.plot(t, true_g, 'r--', lw=2, label='Ground Truth')
            m_g = m_smooth[:, 1]
            std_g = np.sqrt(P_smooth[:, 1, 1])
            ax.fill_between(t, m_g - 1.96*std_g, m_g + 1.96*std_g, color='blue', alpha=0.15)
            
            # FIX: Zoom Logic (Now keyed to true_g instead of the massive Log-Area y)
            g_window = true_g[idx_start:idx_end]
            g_buffer = (np.max(g_window) - np.min(g_window)) * 0.3
            ax.set_xlim(zoom_t_start, zoom_t_end)
            ax.set_ylim(np.min(g_window) - g_buffer, np.max(g_window) + g_buffer)
            ax.set_title(f"Cell {i+1}", fontweight='bold')
            ax.set_xlabel("Time (hours)")
            if i % cols == 0: ax.set_ylabel("Growth Rate")
            if i == 0:
                cloud_proxy = mlines.Line2D([], [], color='gray', alpha=0.5, label='Parameter Uncertainty Cloud')
                handles, labels = ax.get_legend_handles_labels()
                by_label = dict(zip(labels, handles))
                by_label['Parameter Uncertainty Cloud'] = cloud_proxy
                ax.legend(by_label.values(), by_label.keys(), loc='best', fontsize=8)
                
        else:
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
plot_cloud_grid_joint(chain_multiple, log_A_obs_list, true_G=G_list, dt=dt, rows=2, cols=5, n_samples=1000, zoom_t_start=3.0, zoom_t_end=3.5)
# Out:
# Generating Joint MCMC Clouds:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
def calculate_rmse(estimated_g, true_g):
    """Calculates the Root Mean Square Error."""
    return np.sqrt(np.mean((estimated_g - true_g)**2))

def plot_method_competition_violins(chain, log_A_obs_list, true_G, dt):
    """
    Compares Raw Derivative, Moving Average, and Bayesian 2D Smoother.
    Plots the distribution of RMSE across all trajectories.
    """
    n_traj = len(log_A_obs_list)
    windows = [3,5,7,13,15,21,50,100,1000]
    # Storage for the RMSE scores of each method
    rmse_raw = np.zeros(n_traj)
    rmse_ma = np.zeros(n_traj)
    rmse_bayes = np.zeros(n_traj)
    
    print("Running the Smoothing Competition...")
    
    for i in range(n_traj):
        y = log_A_obs_list[i]
        true_g = true_G[i]
        
        # -------------------------------------------------
        # Competitor 1: Raw Finite Difference
        # -------------------------------------------------
        # np.gradient calculates the central difference derivative
        g_raw = np.gradient(y, dt)
        rmse_raw[i] = calculate_rmse(g_raw, true_g)
        
        # -------------------------------------------------
        # Competitor 2: Simple Moving Average (SMA)
        # -------------------------------------------------
        # Convolve a uniform window over the raw derivative
        
        for w in windows:
            window = np.ones(w) / w
            g_ma = np.convolve(g_raw, window, mode='same')
            msd_w = np.sqrt(np.mean((g_ma - true_g)**2))
            results_final.append({'Method': f'MA-{w}', 'MSD': msd_w})
        # Handle the edges that convolution messes up by copying raw
        edge = windows[0] // 2
        g_ma[:edge] = g_raw[:edge]
        g_ma[-edge:] = g_raw[-edge:]
        
        rmse_ma[i] = calculate_rmse(g_ma, true_g)
        
        # -------------------------------------------------
        # Competitor 3: Bayesian 2D RTS Smoother
        # -------------------------------------------------
        # Use our wrapper to get the posterior mean
        g_bayes = rts_smoother_2d(chain, y, dt, n_samples=200, burn_in=5000)
        rmse_bayes[i] = calculate_rmse(g_bayes, true_g)

    # -------------------------------------------------
    # Plotting the Results
    # -------------------------------------------------
    data_to_plot = [rmse_raw, rmse_ma, rmse_bayes]
    labels = ['Raw Derivative', f'Moving Avg\n(w={window_size})', 'Bayesian 2D\nRTS Smoother']
    
    fig, ax = plt.subplots(figsize=(8, 6))
    
    # Create the violins
    parts = ax.violinplot(data_to_plot, showmeans=True, showextrema=True)
    
    # Color coding
    colors = ['lightcoral', 'orange', 'dodgerblue']
    for pc, color in zip(parts['bodies'], colors):
        pc.set_facecolor(color)
        pc.set_edgecolor('black')
        pc.set_alpha(0.7)
        
    # Color the mean/extrema lines
    parts['cmeans'].set_color('black')
    parts['cbars'].set_color('black')
    parts['cmaxes'].set_color('black')
    parts['cmins'].set_color('black')

    # Formatting
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels, fontweight='bold', fontsize=11)
    ax.set_ylabel('Root Mean Square Error (RMSE)', fontweight='bold')
    ax.set_title('Growth Rate Estimation Accuracy\n(Lower RMSE is Better)', fontweight='bold', fontsize=14)
    ax.grid(axis='y', linestyle='--', alpha=0.5)
    
    # Print the exact numbers to the console for your paper/notes!
    print("\n--- Final Average RMSE Scores ---")
    print(f"Raw Derivative: {np.mean(rmse_raw):.4f}")
    print(f"Moving Average: {np.mean(rmse_ma):.4f}")
    print(f"Bayesian RTS:   {np.mean(rmse_bayes):.4f}")
    
    plt.tight_layout()
    plt.show()

# %%
def calculate_rmse(estimated_g, true_g):
    return np.sqrt(np.mean((estimated_g - true_g)**2))

def plot_extended_competition(chain, log_A_obs_list, true_G, dt, windows=[3, 5, 7, 15, 21, 50, 100, 1000]):
    n_traj = len(log_A_obs_list)
    traj_length = len(log_A_obs_list[0])
    valid_windows = [w for w in windows if w < traj_length]
    if len(valid_windows) < len(windows):
        print(f"Note: Dropped windows {set(windows) - set(valid_windows)} because they exceed the {traj_length}-frame trajectory length.")
    rmse_raw = np.zeros(n_traj)
    rmse_bayes = np.zeros(n_traj)
    rmse_ma = {w: np.zeros(n_traj) for w in valid_windows}
    
    print(f"Running Competition across {len(valid_windows)} MA windows. This might take a minute...")
    
    for i in range(n_traj):
        y = log_A_obs_list[i]
        true_g = true_G[i]
        g_raw = np.gradient(y, dt)
        rmse_raw[i] = calculate_rmse(g_raw, true_g)
        for w in valid_windows:
            window = np.ones(w) / w
            g_ma = np.convolve(g_raw, window, mode='same')
            edge = w // 2
            g_ma[:edge] = g_raw[:edge]
            g_ma[-edge:] = g_raw[-edge:]
            
            rmse_ma[w][i] = calculate_rmse(g_ma, true_g)
        g_bayes = rts_smoother_2d(chain, y, dt, n_samples=200, burn_in=5000)
        rmse_bayes[i] = calculate_rmse(g_bayes, true_g)
    data_to_plot = [rmse_raw] + [rmse_bayes] + [rmse_ma[w] for w in valid_windows]
    labels = ['Raw\nDeriv'] + ['Bayesian\n2D'] + [f'MA\n({w})' for w in valid_windows] 
    fig, ax = plt.subplots(figsize=(12, 6))
    
    parts = ax.violinplot(data_to_plot, showmeans=True, showextrema=True)
    colors = ['lightcoral'] + ['orange'] * len(valid_windows) + ['dodgerblue']
    for pc, color in zip(parts['bodies'], colors):
        pc.set_facecolor(color)
        pc.set_edgecolor('black')
        pc.set_alpha(0.7)
        
    for partname in ('cmeans', 'cbars', 'cmaxes', 'cmins'):
        parts[partname].set_color('black')
    expected_raw_rmse = 0.10
    ax.axhline(expected_raw_rmse, color='gray', linestyle='--', alpha=0.7, zorder=0, label='Theoretical Raw Noise')
    ax.legend(loc='upper center', fontsize=10)
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels, fontweight='bold', fontsize=10)
    ax.set_ylabel('Root Mean Square Error (RMSE)', fontweight='bold')
    ax.set_title('Estimation Accuracy: Moving Averages vs. 2D Bayesian Inference', fontweight='bold', fontsize=14)
    ax.grid(axis='y', linestyle='--', alpha=0.5)
    print("\n--- Final Average RMSE Scores ---")
    print(f"Raw Derivative: {np.mean(rmse_raw):.4f}")
    for w in valid_windows:
        print(f"MA (w={w:3d}):    {np.mean(rmse_ma[w]):.4f}")
    print(f"Bayesian RTS:   {np.mean(rmse_bayes):.4f}  <-- THE CHAMPION")
    
    plt.tight_layout()
    plt.show()

# %%
plot_method_competition_violins(chain_multiple, log_A_obs_list, true_G=G_list, dt=dt, window_size=5)
# Out:
# Running the Smoothing Competition...
#
# --- Final Average RMSE Scores ---
# Raw Derivative: 0.1008
# Moving Average: 0.0312
# Bayesian RTS:   0.0170

# %%
plot_extended_competition(chain_multiple, log_A_obs_list, true_G=G_list, dt=dt, windows=[3, 5, 7, 15, 21, 50, 100, 1000])
# Out:
# Running Competition across 8 MA windows. This might take a minute...
#
# --- Final Average RMSE Scores ---
# Raw Derivative: 0.1008
# MA (w=  3):    0.0488
# MA (w=  5):    0.0312
# MA (w=  7):    0.0253
# MA (w= 15):    0.0234
# MA (w= 21):    0.0258
# MA (w= 50):    0.0389
# MA (w=100):    0.0553
# MA (w=1000):    0.1009
# Bayesian RTS:   0.0170  <-- THE CHAMPION
